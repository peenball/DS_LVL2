# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('card_cust.csv')
df.head(6)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
# 5    10006  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000               0.0            2.0        1000.0
# 1                0.250000               4.0            0.0        7000.0
# 2                0.000000               0.0           12.0        7500.0
# 3                0.083333               1.0            1.0        7500.0
# 4                0.000000               0.0            1.0        1200.0
# 5                0.000000               0.0            8.0        1800.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0
# 3     0.000000               NaN          0.000000    12.0
# 4   678.334763        244.791237          0.000000    12.0
# 5  1400.057770       2407.246035          0.000000    12.0

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# CUST_ID                              0
# BALANCE                              0
# BALANCE_FREQUENCY                    0
# PURCHASES                            0
# ONEOFF_PURCHASES                     0
# INSTALLMENTS_PURCHASES               0
# CASH_ADVANCE                         0
# PURCHASES_FREQUENCY                  0
# ONEOFF_PURCHASES_FREQUENCY           0
# PURCHASES_INSTALLMENTS_FREQUENCY     0
# CASH_ADVANCE_FREQUENCY               0
# CASH_ADVANCE_TRX                     0
# PURCHASES_TRX                        0
# CREDIT_LIMIT                         0
# PAYMENTS                             0
# MINIMUM_PAYMENTS                    74
# PRC_FULL_PAYMENT                     0
# TENURE                               0
# dtype: int64

# %%
df.fillna(df['MINIMUM_PAYMENTS'].mean())
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0      10001    40.900749           0.818182      95.40              0.00
# 1      10002  3202.467416           0.909091       0.00              0.00
# 2      10003  2495.148862           1.000000     773.17            773.17
# 3      10004  1666.670542           0.636364    1499.00           1499.00
# 4      10005   817.714335           1.000000      16.00             16.00
# ..       ...          ...                ...        ...               ...
# 995    11029  1250.394614           0.909091     443.99            443.99
# 996    11030     9.503968           1.000000      96.62              0.00
# 997    11031  2285.068731           1.000000       0.00              0.00
# 998    11032  2928.756699           1.000000     160.92              0.00
# 999    11033  1460.178578           1.000000     937.96            100.00
#
#      INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                     95.40      0.000000             0.166667
# 1                      0.00   6442.945483             0.000000
# 2                      0.00      0.000000             1.000000
# 3                      0.00    205.788017             0.083333
# 4                      0.00      0.000000             0.083333
# ..                      ...           ...                  ...
# 995                    0.00      0.000000             0.272727
# 996                   96.62      0.000000             1.000000
# 997                    0.00   1173.310874             0.000000
# 998                  160.92    319.931964             1.000000
# 999                  837.96      0.000000             1.000000
#
#      ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      0.000000                          0.083333
# 1                      0.000000                          0.000000
# 2                      1.000000                          0.000000
# 3                      0.083333                          0.000000
# 4                      0.083333                          0.000000
# ..                          ...                               ...
# 995                    0.272727                          0.000000
# 996                    0.000000                          1.000000
# 997                    0.000000                          0.000000
# 998                    0.000000                          1.000000
# 999                    0.083333                          1.000000
#
#      CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  0.000000               0.0            2.0        1000.0
# 1                  0.250000               4.0            0.0        7000.0
# 2                  0.000000               0.0           12.0        7500.0
# 3                  0.083333               1.0            1.0        7500.0
# 4                  0.000000               0.0            1.0        1200.0
# ..                      ...               ...            ...           ...
# 995                0.000000               0.0            3.0        3500.0
# 996                0.000000               0.0           19.0        4500.0
# 997                0.166667               5.0            0.0        2500.0
# 998                0.333333               5.0           12.0        3000.0
# 999                0.000000               0.0           40.0        1500.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0     201.802084        139.509787          0.000000    12.0
# 1    4103.032597       1072.340217          0.222222    12.0
# 2     622.066742        627.284787          0.000000    12.0
# 3       0.000000       1297.116322          0.000000    12.0
# 4     678.334763        244.791237          0.000000    12.0
# ..           ...               ...               ...     ...
# 995   273.823646        259.715939          0.000000    11.0
# 996  1086.932525         92.217936          0.250000    12.0
# 997   381.672065       1003.265207          0.000000    12.0
# 998  1142.847203       1098.479834          0.000000    12.0
# 999  1186.859701       1320.855292          0.000000    12.0
#
# [1000 rows x 18 columns]

# %%
df['MINIMUM_PAYMENTS'].mean()
# Out:
# 1297.116321697626

# %%
df_base = df.fillna(df['MINIMUM_PAYMENTS'].mean())
df_base.head(3)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
# 2                    0.00               0.0           12.0        7500.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0

# %% [markdown]
# # Q1

# %%
df_base.head(3)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
# 2                    0.00               0.0           12.0        7500.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0

# %%
df_q1 = df_base[['TENURE','BALANCE','CREDIT_LIMIT']].copy()
df_q1.head(3)
# Out:
#    TENURE      BALANCE  CREDIT_LIMIT
# 0    12.0    40.900749        1000.0
# 1    12.0  3202.467416        7000.0
# 2    12.0  2495.148862        7500.0

# %%
df_q1.corr(method='pearson').round(2)
# Out:
#               TENURE  BALANCE  CREDIT_LIMIT
# TENURE          1.00     0.00          0.06
# BALANCE         0.00     1.00          0.47
# CREDIT_LIMIT    0.06     0.47          1.00

# %% [markdown]
# # Q2

# %%
df_base.head(3)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
# 2                    0.00               0.0           12.0        7500.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0

# %%
len(df_base.columns)
# Out:
# 18

# %%
model_nor = StandardScaler().fit(df_base.drop(columns='CUST_ID'))
arr_df_nor = model_nor.transform(df_base.drop(columns='CUST_ID'))
arr_df_nor = pd.DataFrame(arr_df_nor)
arr_df_nor.head(3)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.848768 -0.419879 -0.441936 -0.374048 -0.395301 -0.482354 -0.872701
# 1  0.282791  0.012131 -0.469017 -0.374048 -0.470304  1.878468 -1.282558
# 2  0.029634  0.444141 -0.249538 -0.099717 -0.470304 -0.482354  1.176582
#
#          7         8         9         10        11        12        13  \
# 0 -0.804321 -0.719620 -0.684701 -0.457918 -0.564116 -1.161669 -0.557396
# 1 -0.804321 -0.924403  0.513493  0.065417 -0.628057  0.150025  0.360574
# 2  2.178206 -0.924403 -0.684701 -0.457918 -0.244413  0.259333 -0.458507
#
#          14        15        16
# 0 -0.443725 -0.465544  0.282429
# 1 -0.086159  0.331592  0.282429
# 2 -0.256755 -0.465544  0.282429

# %%
arr_df_nor.columns()

# %% [markdown]
# # ===============================================

# %%
df = pd.read_csv('card_cust.csv')
df.head(6)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
# 5    10006  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000               0.0            2.0        1000.0
# 1                0.250000               4.0            0.0        7000.0
# 2                0.000000               0.0           12.0        7500.0
# 3                0.083333               1.0            1.0        7500.0
# 4                0.000000               0.0            1.0        1200.0
# 5                0.000000               0.0            8.0        1800.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0
# 3     0.000000               NaN          0.000000    12.0
# 4   678.334763        244.791237          0.000000    12.0
# 5  1400.057770       2407.246035          0.000000    12.0

# %%
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df_base = df.copy()
df_base.head(3)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
# 2                    0.00               0.0           12.0        7500.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0
# 2   622.066742        627.284787          0.000000    12.0

# %%
len(df_base)
# Out:
# 1000

# %% [markdown]
# # Q1

# %%
df_q1_sub = df_q1.loc[df_q1['TENURE'] == 12, ]
df_q1_sub[['CREDIT_LIMIT', 'BALANCE']].corr()
# Out:
#               CREDIT_LIMIT   BALANCE
# CREDIT_LIMIT      1.000000  0.460833
# BALANCE           0.460833  1.000000

# %%
ls_corr = []
for t in df_q1['TENURE'].unique():
    df_q1_sub = df_q1.loc[df_q1['TENURE'] == t, ]
    val_corr = df_q1_sub[['CREDIT_LIMIT', 'BALANCE']].corr().iloc[0, 1]
    ls_corr = ls_corr + [val_corr]

# %%
pd.Series(ls_corr, index = df_q1['TENURE'].unique()).reset_index().round(2)
# Out:
#    index     0
# 0   12.0  0.46
# 1    8.0  0.82
# 2   11.0  0.38
# 3    9.0  0.09
# 4   10.0  0.29
# 5    7.0  0.95
# 6    6.0  0.87

# %%
df_q1.groupby('TENURE')['CREDIT_LIMIT', 'BALANCE'].corr().round(2)
# Out:
# C:\Users\hyojin\AppData\Local\Temp\ipykernel_8188\4215311885.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_q1.groupby('TENURE')['CREDIT_LIMIT', 'BALANCE'].corr().round(2)
#                      CREDIT_LIMIT  BALANCE
# TENURE
# 6.0    CREDIT_LIMIT          1.00     0.87
#        BALANCE               0.87     1.00
# 7.0    CREDIT_LIMIT          1.00     0.95
#        BALANCE               0.95     1.00
# 8.0    CREDIT_LIMIT          1.00     0.82
#        BALANCE               0.82     1.00
# 9.0    CREDIT_LIMIT          1.00     0.09
#        BALANCE               0.09     1.00
# 10.0   CREDIT_LIMIT          1.00     0.29
#        BALANCE               0.29     1.00
# 11.0   CREDIT_LIMIT          1.00     0.38
#        BALANCE               0.38     1.00
# 12.0   CREDIT_LIMIT          1.00     0.46
#        BALANCE               0.46     1.00

# %%
df_q1.groupby('TENURE')['CREDIT_LIMIT', 'BALANCE'].corr().xs('CREDIT_LIMIT', level=1)
# Out:
# C:\Users\hyojin\AppData\Local\Temp\ipykernel_8188\700592070.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_q1.groupby('TENURE')['CREDIT_LIMIT', 'BALANCE'].corr().xs('CREDIT_LIMIT', level=1)
#         CREDIT_LIMIT   BALANCE
# TENURE
# 6.0              1.0  0.868056
# 7.0              1.0  0.948405
# 8.0              1.0  0.820696
# 9.0              1.0  0.085474
# 10.0             1.0  0.291482
# 11.0             1.0  0.380360
# 12.0             1.0  0.460833

# %% [markdown]
# # Q2

# %%
df_q2 = df.drop(columns = 'CUST_ID').copy()
df_q2.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182       95.4               0.0
# 1  3202.467416           0.909091        0.0               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000    12.0
# 1  4103.032597       1072.340217          0.222222    12.0

# %%
df_q2_nor = StandardScaler().fit_transform(df_q2)
df_q2_nor = pd.DataFrame(df_q2_nor, columns = df_q2.columns)
df_q2_nor.head(2)
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.848768          -0.419879  -0.441936         -0.374048
# 1  0.282791           0.012131  -0.469017         -0.374048
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.395301     -0.482354            -0.872701
# 1               -0.470304      1.878468            -1.282558
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.804321                         -0.719620
# 1                   -0.804321                         -0.924403
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0               -0.684701         -0.457918      -0.564116     -1.161669
# 1                0.513493          0.065417      -0.628057      0.150025
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0 -0.557396         -0.443725         -0.465544  0.282429
# 1  0.360574         -0.086159          0.331592  0.282429

# %%
list(range(2,6))
# Out:
# [2, 3, 4, 5]

# %%
ls_sil = []

for k in range(2,6):
    model_km = KMeans(n_clusters = k, random_state = 1234)
    model_km.fit(df_q2_nor)
    val_sil = silhouette_score(df_q2_nor, labels = model_km.labels_)
    ls_sil = ls_sil + [val_sil]
# Out:
# C:\Users\hyojin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hyojin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hyojin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\hyojin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
ls_sil
# Out:
# [0.3075281530456079,
#  0.19636128772937608,
#  0.20715098494639902,
#  0.19274056144483248]

# %%
model_km = KMeans(n_clusters = 2, random_state = 1234)
model_km.fit(df_q2_nor)
# Out:
# C:\Users\hyojin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=1234)

# %%
df_q2['cluster'] = model_km.labels_
df_q2.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182       95.4               0.0
# 1  3202.467416           0.909091        0.0               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00               0.0            2.0        1000.0
# 1                    0.25               4.0            0.0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000    12.0        0
# 1  4103.032597       1072.340217          0.222222    12.0        0

# %%
df_q2['cluster'].value_counts()
# Out:
# 0    802
# 1    198
# Name: cluster, dtype: int64

# %%
df_q2.groupby('cluster')['ONEOFF_PURCHASES'].mean().round(2)
# Out:
# cluster
# 0     340.23
# 1    3946.19
# Name: ONEOFF_PURCHASES, dtype: float64

# %% [markdown]
# # Q3

# %%
df_train = df_base.loc[(df_base['CUST_ID'] % 4) != 0, ]
df_test  = df_base.loc[(df_base['CUST_ID'] % 4) == 0, ]

# %%
len(df_train), len(df_test)
# Out:
# (752, 248)

# %%
model_dt = DecisionTreeRegressor(random_state = 1234)
model_dt.fit(X = df_train.drop(columns = ['CUST_ID', 'ONEOFF_PURCHASES']),
             y = df_train['ONEOFF_PURCHASES'])
pred = model_dt.predict(df_test.drop(columns = ['CUST_ID', 'ONEOFF_PURCHASES']))

# %%
pred[:4]
# Out:
# array([1500.,    0., 1490.,    0.])

# %%
from sklearn.metrics import mean_squared_error

# %%
round(mean_squared_error(y_true = df_test['ONEOFF_PURCHASES'],
                         y_pred = pred) ** 0.5, 1)
# Out:
# 1039.2
